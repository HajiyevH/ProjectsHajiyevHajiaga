# %%
import pandas as pd
import numpy as np

dfplayer = pd.read_csv("Users/hajiaga/Desktop/DataScience/players.csv")

dfteam = pd.read_csv("Users/hajiaga/Desktop/DataScience/teams.csv")

dfteam
# Out:
#     players_used  avg_age  possession  games  games_starts  minutes  \
# 0           20.0     25.2        43.2    6.0          66.0    540.0
# 1           22.0     25.9        57.1    8.0          88.0    750.0
# 2           22.0     30.0        51.1    8.0          88.0    750.0
# 3           25.0     27.2        58.5    8.0          88.0    720.0
# 4           23.0     28.2        58.4    8.0          88.0    720.0
# 5           22.0     26.9        49.0    6.0          66.0    540.0
# 6           23.0     28.4        53.2    6.0          66.0    540.0
# 7           23.0     27.0        47.2    6.0          66.0    540.0
# 8           23.0     28.1        44.6    8.0          88.0    720.0
# 9           24.0     27.7        38.8    8.0          88.0    720.0
# 10          24.0     24.8        54.5    6.0          66.0    540.0
# 11          20.0     29.2        53.2    6.0          66.0    540.0
# 12          22.0     29.7        52.5    8.0          88.0    750.0
# ...
